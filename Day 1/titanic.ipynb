# %% [markdown]
# <a href="https://colab.research.google.com/github/ciril7/AI-ML-Intern/blob/main/Day%201/titanic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/titanic uncleaned.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
df.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 413        False     False   False  False  False   True  False  False   False
# 414        False     False   False  False  False  False  False  False   False
# 415        False     False   False  False  False  False  False  False   False
# 416        False     False   False  False  False   True  False  False   False
# 417        False     False   False  False  False   True  False  False   False
#
#       Fare  Cabin  Embarked
# 0    False   True     False
# 1    False   True     False
# 2    False   True     False
# 3    False   True     False
# 4    False   True     False
# ..     ...    ...       ...
# 413  False   True     False
# 414  False  False     False
# 415  False   True     False
# 416  False   True     False
# 417  False   True     False
#
# [418 rows x 12 columns]

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
df['Age_mean_imputed']=df['Age'].fillna(df['Age'])

# %%
df['Age_median_imputed']=df['Age'].fillna(df['Age'].median())

# %%
df['Cabin_mode_imputed']=df['Cabin'].fillna(df['Cabin'].mode()[0])

# %%
df[['Age','Age_mean_imputed','Age_median_imputed']]
# Out:
#       Age  Age_mean_imputed  Age_median_imputed
# 0    34.5              34.5                34.5
# 1    47.0              47.0                47.0
# 2    62.0              62.0                62.0
# 3    27.0              27.0                27.0
# 4    22.0              22.0                22.0
# ..    ...               ...                 ...
# 413   NaN               NaN                27.0
# 414  39.0              39.0                39.0
# 415  38.5              38.5                38.5
# 416   NaN               NaN                27.0
# 417   NaN               NaN                27.0
#
# [418 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set(style="whitegrid")

# %%
plt.figure(figsize=(10,6))
sns.boxplot(data=df,x='Pclass',y='Age',palette='pastel')
plt.title('Boxplot of Age by Passenger Class')
plt.xlabel('Passenger Class')
plt.ylabel('Age')
# Out:
# /tmp/ipykernel_951/1588006797.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df,x='Pclass',y='Age',palette='pastel')
# Text(0, 0.5, 'Age')

# %%
plt.figure(figsize=(10,6))
sns.boxplot(data=df,x='Pclass',y='Survived',palette='pastel')
plt.title('Boxplot of Survived Passenger Class')
plt.xlabel('Passenger Class')
plt.ylabel('Survived')
# Out:
# /tmp/ipykernel_951/1419506980.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df,x='Pclass',y='Survived',palette='pastel')
# Text(0, 0.5, 'Survived')

# %%
plt.figure(figsize=(10,6))
sns.barplot(data=df,x='Pclass',y='Age',palette='pastel')
plt.title('bar plot of Age by Passenger Class')
plt.xlabel('Passenger Class')
plt.ylabel('Age')
# Out:
# /tmp/ipykernel_951/492627766.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df,x='Pclass',y='Age',palette='pastel')
# Text(0, 0.5, 'Age')

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder_data=df.copy()

# %%
label_encoder = LabelEncoder()
encoder_data['Sex_Label'] = label_encoder.fit_transform(encoder_data['Sex'])

# %%
one_hot_encoded = pd.get_dummies(encoder_data['Embarked'], prefix='Embarked')
encoder_data = pd.concat([encoder_data, one_hot_encoded], axis=1)

# Since 'Pclass' is ordinal, we can create a mapped column for demonstration.
pclass_mapping = {1: 'First', 2: 'Second', 3: 'Third'}
# 3. Ordinal Encoding For p class
encoder_data['Pclass_Category'] = encoder_data['Pclass'].map(pclass_mapping)

# Display the resulting dataset with relevant encoded columns
print(encoder_data[['Sex', 'Sex_Label', 'Embarked', 'Embarked_Q', 'Embarked_S', 'Embarked_C', 'Pclass', 'Pclass_Category']].head())
# Out:
#       Sex  Sex_Label Embarked  Embarked_Q  Embarked_S  Embarked_C  Pclass  \
# 0    male          1        Q        True       False       False       3
# 1  female          0        S       False        True       False       3
# 2    male          1        Q        True       False       False       2
# 3    male          1        S       False        True       False       3
# 4  female          0        S       False        True       False       3
#
#   Pclass_Category
# 0           Third
# 1           Third
# 2          Second
# 3           Third
# 4           Third

# %%
from sklearn.preprocessing import MinMaxScaler,StandardScaler,RobustScaler

# %%
file_path='/content/titanic uncleaned.csv'

# %%
titanic_data=pd.read_csv(file_path)

# %%
numerical_columns=['Age','Fare','Pclass']

# %%
titanic_data.dropna(subset=numerical_columns,inplace=True)

# %%
minmax_scaler=MinMaxScaler()
standard_scaler=StandardScaler()
robust_scaler=RobustScaler()

# %%
titanic_data['Age_minmax']=minmax_scaler.fit_transform(titanic_data[['Age']])
titanic_data['Fare_MinMax']=minmax_scaler.fit_transform(titanic_data[['Fare']])

# %%
titanic_data['Age_Standard']=standard_scaler.fit_transform(titanic_data[['Age']])
titanic_data['Fare_Standard']=standard_scaler.fit_transform(titanic_data[['Fare']])

# %%
titanic_data['Age_Robust']=robust_scaler.fit_transform(titanic_data[['Age']])
titanic_data['Fare_Robust']=robust_scaler.fit_transform(titanic_data[['Fare']])

# %%
titanic_data[['Age','Age_minmax','Age_Standard','Age_Robust']]
# Out:
#       Age  Age_minmax  Age_Standard  Age_Robust
# 0    34.5    0.452723      0.306657    0.416667
# 1    47.0    0.617566      1.194236    1.111111
# 2    62.0    0.815377      2.259331    1.944444
# 3    27.0    0.353818     -0.225890    0.000000
# 4    22.0    0.287881     -0.580922   -0.277778
# ..    ...         ...           ...         ...
# 409   3.0    0.037320     -1.930042   -1.333333
# 411  37.0    0.485692      0.484173    0.555556
# 412  28.0    0.367005     -0.154884    0.055556
# 414  39.0    0.512066      0.626186    0.666667
# 415  38.5    0.505473      0.590683    0.638889
#
# [331 rows x 4 columns]
